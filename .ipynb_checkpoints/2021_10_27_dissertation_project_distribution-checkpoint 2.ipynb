# %% [markdown]
# # Project allocation

# %%
import numpy as np
import pandas as pd
import openpyxl as pxl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Student Numbers

# %%
N_robotics = 95

N_biorobotics = 23

N_A_robotics = 25

N_students = N_robotics + N_biorobotics + N_A_robotics

N_students
# Out:
# 143

# %% [markdown]
# # UoB Supervisors in data base

# %%
supervisors = pd.read_excel('data/project_database_2021.xlsx', sheet_name='supervisors')
supervisors.rename(columns={'full name': 'full_name'}, inplace=True)
supervisors[supervisors.UoB == 'X']#["UoB"=="X"].head(150)
# Out:
# MSc Robotics
# MSc BioRobotics
# MSc Aerial Robotics
# UoB
# UWE
# username
# firstname
# surname
# full_name
# email
# profile
# can_be_main_supervisor
# max_students
# 0       X
# 1     NaN
# 2     NaN
# 3       X
# 4       X
#      ...
# 67    NaN
# 68    NaN
# 69    NaN
# 70     36
# 71    NaN
# Name: UWE, Length: 72, dtype: object

# %% [markdown]
# # Responses to phase 1 data collection

# %%
cols = ['full_name', 'register', 'email', 'dept', 'N_proj', 'kwords', 'prog']
resp = pd.read_excel('data/project_database_2021.xlsx', sheet_name='response_round_1_UoB', names=cols)
resp.head(6)
# Out:
#          full_name register                        email  \
# 0  Hemma Philamore      Yes    hemma.philamore@gmail.com
# 1    Helmut Hauser      Yes  helmut.hauser@bristol.ac.uk
# 2     Nikolai Bode       No                          NaN
# 3     Dandan Zhang      Yes        ye21623@bristol.ac.uk
# 4         Tom Hill       No                          NaN
# 5    Andrew Hinitt      Yes  andrew.hinitt@bristol.ac.uk
#
#                       dept  N_proj  \
# 0  Engineering Mathematics     3.0
# 1  Engineering Mathematics     3.0
# 2                      NaN     NaN
# 3  Engineering Mathematics     5.0
# 4                      NaN     NaN
# 5  Engineering Mathematics     1.0
#
#                                               kwords  \
# 0                   soft robotics, bio-hybrid robots
# 1  morphological computation, locomotion, soft ro...
# 2                                                NaN
# 3  Robot learning ( Machine Learning and Deep Lea...
# 4                                                NaN
# 5            Soft Robotics Medical Implant Surgical
#
#                             prog
# 0  MSc Robotics;MSc BioRobotics;
# 1  MSc BioRobotics;MSc Robotics;
# 2                            NaN
# 3  MSc BioRobotics;MSc Robotics;
# 4                            NaN
# 5                  MSc Robotics;

# %% [markdown]
# # Programme names re-configured so programmes appear in consistent order

# %%
# Split strings of programmes, remove spaces, sort in alphabetical order, convert string to list

#print([', '.join(sorted(list(filter(lambda x: x != "", P.split(';')))))  if P != 'NaN' else P for P in resp['prog'].fillna('NaN')] )
#pr('NaN')])

resp['prog'] = [', '.join(sorted(list(filter(lambda x: x != "", P.split(';')))))  if P != float('NaN') else P for P in resp['prog'].fillna('NaN')]

resp.head(60)
# Out:
#                       full_name register                                email  \
# 0               Hemma Philamore      Yes            hemma.philamore@gmail.com
# 1                 Helmut Hauser      Yes          helmut.hauser@bristol.ac.uk
# 2                  Nikolai Bode       No                                  NaN
# 3                  Dandan Zhang      Yes                ye21623@bristol.ac.uk
# 4                      Tom Hill       No                                  NaN
# 5                 Andrew Hinitt      Yes          andrew.hinitt@bristol.ac.uk
# 6                   Paul O'Dowd      Yes             paul.odowd@bristol.ac.uk
# 7        Benjamin Ward-Cherrier      Yes        b.ward-cherrier@bristol.ac.uk
# 8                 Nahian Rahman      Yes                jf20027@bristol.ac.uk
# 9            Thomas Gorochowski       No                                  NaN
# 10                    Keren Yue      Yes              keren.yue@bristol.ac.uk
# 11          Lindsay Roger Clare       No                                  NaN
# 12               Hermes Gadelha      Yes                       Hermes Gadelha
# 13                    Qiukai Qi      Yes              qiukai.qi@bristol.ac.uk
# 14                    Qiukai Qi      Yes              qiukai.qi@bristol.ac.uk
# 15                  Edmund Hunt      Yes            edmund.hunt@bristol.ac.uk
# 16  Richard Suphapol Diteesawat      Yes     richard.diteesawat@bristol.ac.uk
# 17                 James Wilson      Yes               j.wilson@bristol.ac.uk
# 18         Lucio Rafael Salinas      Yes          lucio.salinas@bristol.ac.uk
# 19             Saurabh Upadhyay       No                                  NaN
# 20              Arthur Richards      Yes        arthur.richards@bristol.ac.uk
# 21             Christian Romero      Yes                cr16031@bristol.ac.uk
# 22                  Andrew Conn      Yes                 a.conn@bristol.ac.uk
# 23                Shane Windsor      Yes          shane.windsor@bristol.ac.uk
# 24               Hirad Goudarzi      Yes         hirad.goudarzi@bristol.ac.uk
# 25                Martin Garrad      Yes               m.garrad@bristol.ac.uk
# 26               Sebastian East      Yes         sebastian.east@bristol.ac.uk
# 27                     Yuan Gao      Yes             yuan21.gao@bristol.ac.uk
# 28                    Mickey Li      Yes              mickey.li@bristol.ac.uk
# 29       Mohammad Naghavi Zadeh      Yes         m.naghavizadeh@bristol.ac.uk
# 30                 Chanelle Lee      Yes                c.l.lee@bristol.ac.uk
# 31                Nathan Lepora      Yes               n.lepora@bristol.ac.uk
# 32              Efi Psomopoulou      Yes        efi.psomopoulou@bristol.ac.uk
# 33               Jonathan Lawry       No                                  NaN
# 34                      Yao Lu        No                                  NaN
# 35                 Namid Shatil       No                                  NaN
# 36                   Dima Damen       No                                  NaN
# 37            Antonia Tzemanaki       No                                  NaN
# 38                   Emma Young       No                                  NaN
# 39                  Emma Milner       No                                  NaN
# 40                    Weiru Liu       No                                  NaN
# 41              Kevin McAreavey       No                                  NaN
# 42                 James Wilson      Yes               j.wilson@bristol.ac.uk
# 43                 Kerstin Eder       No                                  NaN
# 44               Marc Holderied       No                                  NaN
# 45               Tom Richardson      Yes      thomas.richardson@bristol.ac.uk
# 46                    Yanan Liu       No                                  NaN
# 47                  Mark Schenk       No                                  NaN
# 48               Sebastian East      Yes         sebastian.east@bristol.ac.uk
# 49        Walterio Mayol-Cuevas      Yes  walterio.mayol-cuevas@bristol.ac.uk
# 50                Lucia Marucci      Yes          lucia.marucci@bristol.ac.uk
# 51                Sabine Hauert      Yes          sabine.hauert@bristol.ac.uk
# 52               Alan Champneys       No                                  NaN
# 53                Elliott Scott      Yes                es12723@bristol.ac.uk
# 54                  Edmund Hunt      Yes            edmund.hunt@bristol.ac.uk
# 55               Conor Houghton      Yes         conor.houghton@bristol.ac.uk
# 56            Johanna Benn-Blee      Yes      johanna.benn-blee@bristol.ac.uk
#
#                        dept  N_proj  \
# 0   Engineering Mathematics     3.0
# 1   Engineering Mathematics     3.0
# 2                       NaN     NaN
# 3   Engineering Mathematics     5.0
# 4                       NaN     NaN
# 5   Engineering Mathematics     1.0
# 6   Engineering Mathematics     5.0
# 7   Engineering Mathematics     2.0
# 8   Engineering Mathematics     0.0
# 9                       NaN     NaN
# 10  Engineering Mathematics     2.0
# 11                      NaN     NaN
# 12  Engineering Mathematics     2.0
# 13  Engineering Mathematics     2.0
# 14  Engineering Mathematics     2.0
# 15  Engineering Mathematics     2.0
# 16  Engineering Mathematics     2.0
# 17  Engineering Mathematics     2.0
# 18  Engineering Mathematics     1.0
# 19                      NaN     NaN
# 20                Aerospace     3.0
# 21  Engineering Mathematics     2.0
# 22   Mechanical Engineering     2.0
# 23                Aerospace     5.0
# 24                Aerospace     1.0
# 25  Engineering Mathematics     1.0
# 26                Aerospace     2.0
# 27                Aerospace     2.0
# 28                Aerospace     1.0
# 29  Engineering Mathematics     1.0
# 30  Engineering Mathematics     2.0
# 31  Engineering Mathematics     2.0
# 32  Engineering Mathematics     1.0
# 33                      NaN     NaN
# 34                      NaN     NaN
# 35                      NaN     NaN
# 36                      NaN     NaN
# 37                      NaN     NaN
# 38                      NaN     NaN
# 39                      NaN     NaN
# 40                      NaN     NaN
# 41                      NaN     NaN
# 42  Engineering Mathematics     2.0
# 43                      NaN     NaN
# 44                      NaN     NaN
# 45                Aerospace     4.0
# 46                      NaN     NaN
# 47                      NaN     NaN
# 48                Aerospace     1.0
# 49         Computer Science     2.0
# 50  Engineering Mathematics     1.0
# 51  Engineering Mathematics     5.0
# 52                      NaN     NaN
# 53  Engineering Mathematics     1.0
# 54  Engineering Mathematics     2.0
# 55         Computer Science     1.0
# 56  Engineering Mathematics     1.0
#
#                                                kwords  \
# 0                    soft robotics, bio-hybrid robots
# 1   morphological computation, locomotion, soft ro...
# 2                                                 NaN
# 3   Robot learning ( Machine Learning and Deep Lea...
# 4                                                 NaN
# 5             Soft Robotics Medical Implant Surgical
# 6   swarm robotics, evolutionary robotics, evoluti...
# 7   Tactile robotics, neuromorphic processing, spi...
# 8   Grasping, Mechanism, Kinematics, Soft robot bu...
# 9                                                 NaN
# 10  medical robotics, rehabilitation device, soft ...
# 11                                                NaN
# 12  Soft-robotics of mícrobes, self locomotion, ar...
# 13      Biorobotics; Tactile Sensing and Perception;
# 14  Bio-inspired Robotics; Tactile Sensing and Per...
# 15  swarm robotics, behavioural plasticity, behavi...
# 16  Soft robotic artificial muscles, wearable assi...
# 17  Swarm Robotics, Trustworthiness, Digital Twin,...
# 18  Digital twin, mobile robots, teleoperation, hu...
# 19                                                NaN
# 20                      Drones; Autonomy; Multi-agent
# 21                           Flapping Aerial Robotics
# 22  soft robotics, bio-inspired, locomotion, healt...
# 23  bio-inspiration, unmanned air vehicles, bird f...
# 24  drone safety, mission planning, flight control...
# 25                                      Soft Robotics
# 26  Optimal Control, Model Predictive Control, Mac...
# 27  multi-agent simulation, model predictive contr...
# 28  Practical Software Engineering for Drones, Mul...
# 29  Soft Robotics, Mechanical Metamaterials, 3D pr...
# 30  multi-agent systems, decision making, swarm ro...
# 31  Robot learning, dexterous manipulation, tactil...
# 32  Grasping, Manipulation, physical Human-Robot I...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42  Swarm Robotics, Trustworthy Robotics, Informat...
# 43                                                NaN
# 44                                                NaN
# 45   Drones systems, applications, control & sensing.
# 46                                                NaN
# 47                                                NaN
# 48                   Control Theory, Machine Learning
# 49  Deep Learning for Robotocs, Computer Vision, H...
# 50  microfluidics, feedback control, mammalian cells
# 51  Swarm robotics, swarms for intralogistics, art...
# 52                                                NaN
# 53  Bio-Inspired Robotics, fluid dynamics, swarm r...
# 54  swarm robotics, collective behaviour, hardware...
# 55  neurolinguistics, language games, neuroscience...
# 56  biofilms, bacteria, environmental monitoring, ...
#
#                                                  prog
# 0                       MSc BioRobotics, MSc Robotics
# 1                       MSc BioRobotics, MSc Robotics
# 2                                                 NaN
# 3                       MSc BioRobotics, MSc Robotics
# 4                                                 NaN
# 5                                        MSc Robotics
# 6                       MSc BioRobotics, MSc Robotics
# 7                       MSc BioRobotics, MSc Robotics
# 8                       MSc BioRobotics, MSc Robotics
# 9                                                 NaN
# 10                                    MSc BioRobotics
# 11                                                NaN
# 12                      MSc BioRobotics, MSc Robotics
# 13                                    MSc BioRobotics
# 14                      MSc BioRobotics, MSc Robotics
# 15                      MSc BioRobotics, MSc Robotics
# 16                                       MSc Robotics
# 17                      MSc BioRobotics, MSc Robotics
# 18                  MSc Aerial Robotics, MSc Robotics
# 19                                                NaN
# 20                  MSc Aerial Robotics, MSc Robotics
# 21                  MSc Aerial Robotics, MSc Robotics
# 22                      MSc BioRobotics, MSc Robotics
# 23                                MSc Aerial Robotics
# 24                  MSc Aerial Robotics, MSc Robotics
# 25                      MSc BioRobotics, MSc Robotics
# 26  MSc Aerial Robotics, MSc BioRobotics, MSc Robo...
# 27                  MSc Aerial Robotics, MSc Robotics
# 28                  MSc Aerial Robotics, MSc Robotics
# 29  MSc Aerial Robotics, MSc BioRobotics, MSc Robo...
# 30                      MSc BioRobotics, MSc Robotics
# 31                      MSc BioRobotics, MSc Robotics
# 32                                       MSc Robotics
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                      MSc BioRobotics, MSc Robotics
# 43                                                NaN
# 44                                                NaN
# 45                                MSc Aerial Robotics
# 46                                                NaN
# 47                                                NaN
# 48                                MSc Aerial Robotics
# 49  MSc Aerial Robotics, MSc BioRobotics, MSc Robo...
# 50                                    MSc BioRobotics
# 51                      MSc BioRobotics, MSc Robotics
# 52                                                NaN
# 53                      MSc BioRobotics, MSc Robotics
# 54                      MSc BioRobotics, MSc Robotics
# 55                                    MSc BioRobotics
# 56                                    MSc BioRobotics

# %% [markdown]
# # Basic Metrics

# %%
all_resp = resp.full_name                                             # total responses


withdraw = resp[resp.register == 'No'].full_name                      # init primary supervisors who withdrew
#N_withdraw = resp[resp.register == 'No'].shape[0]                    # number of primary supervisors who withdrew

init = supervisors[supervisors.UoB == 'X'].full_name.append(withdraw) # init primary supervisors 

init_resp    = set(init) & set(resp.full_name) 

init_no_resp = set(init) - set(resp.full_name)

new          = set(resp.full_name) - set(init)

N_projects   = sum(resp.N_proj.dropna())

primary_confirmed = set(supervisors[supervisors.UoB == 'X'].full_name) - set(init_no_resp)

average_projects_primary = resp[resp['full_name'].isin(primary_confirmed)].N_proj.mean()




print('N primary supervisors contacted initially: ', len(init))

print('N responses (total): ', len(all_resp))

print('N responded primary supervisors: ', len(init_resp))

print()

print('N responded new (PDRAs?): ', len(new))
print(new, end='\n\n')

#print('Response rate (primary supervisors):', len(init_resp)/len(init)*100, '%')

print('N did not respond primary supervisors: ', len(init_no_resp))
print(init_no_resp, end='\n\n')

print('N primary supervisors confirmed:', len(primary_confirmed))
print(primary_confirmed, end='\n\n')

print('N primary supervisors withdrew:', len(withdraw))
print(set(withdraw), end='\n\n')




print('N total projects: ', N_projects)

print('average N projects contributed by primary supervsiors: ', round(average_projects_primary, 3))

print('average N projects needed from primary supervsiors: ', round(N_projects / len(primary_confirmed),2))

UWE_projects = 60
print('N total projects (inc. UWE): ', N_projects + UWE_projects)


#print('Forecast total projects (assume unresponsive supervisors submit 3 projects each)', N_projects + 3*len(init_no_resp))
# Out:
# N primary supervisors contacted initially:  45
# N responses (total):  57
# N responded primary supervisors:  37
#
# N responded new (PDRAs?):  16
# {'James Wilson', 'Christian Romero', 'Efi Psomopoulou', 'Andrew Hinitt', 'Keren Yue', 'Qiukai Qi', 'Richard Suphapol Diteesawat', 'Elliott Scott', 'Nahian Rahman', 'Mohammad Naghavi Zadeh', 'Mickey Li', 'Hirad Goudarzi', 'Martin Garrad', 'Yuan Gao', 'Lucio Rafael Salinas', 'Johanna Benn-Blee'}
#
# N did not respond primary supervisors:  8
# {'David Barton', 'Ahmed Khalil', 'Michael Elkington', 'Steve Burrow ', 'Andrew  Calway ', 'Karen Aplin', 'Dimitra Simeonidou', 'Jonathan Rossiter'}
#
# N primary supervisors confirmed: 18
# {'Arthur Richards', 'Edmund Hunt', 'Andrew Conn', 'Dandan Zhang', 'Helmut Hauser', 'Hermes Gadelha', 'Chanelle Lee', 'Shane Windsor', 'Tom Richardson', 'Lucia Marucci', 'Sebastian East', 'Sabine Hauert', "Paul O'Dowd", 'Nathan Lepora', 'Conor Houghton', 'Benjamin Ward-Cherrier', 'Hemma Philamore', 'Walterio Mayol-Cuevas'}
#
# N primary supervisors withdrew: 19
# {'Kerstin Eder', 'Lindsay Roger Clare', 'Kevin McAreavey', 'Jonathan Lawry', 'Yanan Liu', 'Saurabh Upadhyay', 'Emma Young', 'Marc Holderied', 'Yao Lu ', 'Weiru Liu', 'Nikolai Bode', 'Namid Shatil', 'Dima Damen', 'Alan Champneys', 'Mark Schenk', 'Thomas Gorochowski', 'Tom Hill', 'Antonia Tzemanaki', 'Emma Milner'}
#
# N total projects:  79.0
# average N projects contributed by primary supervsiors:  2.7
# average N projects needed from primary supervsiors:  4.39
# N total projects (inc. UWE):  139.0

# %% [markdown]
# # Projects and supervisors by programme and dept.

# %%
def plot_data(data, y_label, filename):
    
    """ N PROJECTS / N SUPERVISORS by dept and programme """
    
    # data = resp.groupby(['dept','prog'])['N_proj'].sum().unstack().fillna(0)

    # Reorder programmes
    data = data[sorted(list(data.columns.values), key=len, reverse=True)]

    # Create four axes 
    fig, axs = plt.subplots(2, 2)#, sharex='all', sharey='all')

    # BAR CHART: programme
    sum_P = data.sum(axis=0, skipna=True) # sum for each programme
    x_pos = np.arange(len(sum_P))         # array with the same number of positions as bars
    axs[0, 0].bar(x_pos, sum_P);
    axs[0, 0].tick_params(axis='x',which='both', bottom=False,top=False,labelbottom=False) 
    axs[0, 0].set_ylabel(y_label);
    #axs[0, 0].set_title('Programme');
    axs[0, 0].set_xlabel('Programme')    
    axs[0, 0].xaxis.set_label_position('top') 

    # BAR CHART: dept
    sum_D = data.sum(axis=1, skipna=True) # sum for each dept
    x_pos = np.arange(len(sum_D))         
    axs[1, 1].barh(x_pos, sum_D[::-1])
    axs[1, 1].tick_params(axis='y',which='both', left=False, right=False,labelleft=False) 
    axs[1, 1].set_xlabel(y_label);
    #axs[1, 1].set_title('Dept');
    axs[1, 1].set_ylabel('Dept')    
    axs[1, 1].yaxis.set_label_position('right') 

    # EMPTY SUBPLOT
    axs[0, 1].axis('off')

    # COLOUR MAP: N projects by department and programme
    axs[1, 0].matshow(data, cmap='Reds')
    # Value shown in each cell
    for (i, j), z in np.ndenumerate(data):
        axs[1, 0].text(j, i, '{:0.1f}'.format(z), ha='center', va='center')

    # text to use as labels
    axs[1, 0].set_xticks(np.arange(data.shape[1]))
    axs[1, 0].set_xticklabels(list(data.columns.values))
    axs[1, 0].set_yticks(np.arange(data.shape[0]))
    axs[1, 0].set_yticklabels(data.index.values.tolist())

    # Set ticks on bottom
    axs[1, 0].tick_params(axis="x", bottom=True, top=False, labelbottom=True, labeltop=False)

    # Rotate and align bottom ticklabels
    plt.setp([tick.label1 for tick in axs[1, 0].xaxis.get_major_ticks()], rotation=90,
             ha="right", va="center", rotation_mode="anchor")

    fig.suptitle(y_label + 'by dept and programme ')

    plt.savefig(filename,dpi=300, bbox_inches = "tight")

    sum_P_projects = sum_P

# %%
### N PROJECTS by dept and programme 
plot_data(resp.groupby(['dept','prog'])['N_proj'].sum().unstack().fillna(0), 
          'N projects', 
          'img/projects.png')

### N SUPERVISORS by dept and programme 
plot_data(resp[~resp['full_name'].isin(new)].groupby(['dept','prog'])['N_proj'].count().unstack().fillna(0), 
          'N supervisors', 
          'img/supervisors.png')

# %%
sum_P_projects
# Out:
# prog
# MSc Aerial Robotics, MSc BioRobotics, MSc Robotics     5.0
# MSc Aerial Robotics, MSc Robotics                     10.0
# MSc BioRobotics, MSc Robotics                         43.0
# MSc Aerial Robotics                                   10.0
# MSc BioRobotics                                        7.0
# MSc Robotics                                           4.0
# dtype: float64

# %%
print(type(sum_P_projects))

sum_P = pd.concat([sum_P_projects, sum_P_supervisors], axis=1)
print(type(sum_P))
sum_P.rename(columns={0: 'projects', 1: 'primary_supervisors'}, inplace=True)
sum_P
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
#                                                     projects  \
# MSc Aerial Robotics, MSc BioRobotics, MSc Robotics       5.0
# MSc Aerial Robotics, MSc Robotics                       10.0
# MSc BioRobotics, MSc Robotics                           43.0
# MSc Aerial Robotics                                     10.0
# MSc BioRobotics                                          7.0
# MSc Robotics                                             4.0
#
#                                                     primary_supervisors
# MSc Aerial Robotics, MSc BioRobotics, MSc Robotics                  2.0
# MSc Aerial Robotics, MSc Robotics                                   1.0
# MSc BioRobotics, MSc Robotics                                      12.0
# MSc Aerial Robotics                                                 3.0
# MSc BioRobotics                                                     2.0
# MSc Robotics                                                        NaN

# %%
sum_P['p:s_ratio'] = sum_P['projects'][:5] / sum_P['primary_supervisors'][:5]
sum_P
# Out:
#                                                     projects  \
# MSc Aerial Robotics, MSc BioRobotics, MSc Robotics       5.0
# MSc Aerial Robotics, MSc Robotics                       10.0
# MSc BioRobotics, MSc Robotics                           43.0
# MSc Aerial Robotics                                     10.0
# MSc BioRobotics                                          7.0
# MSc Robotics                                             4.0
#
#                                                     primary_supervisors  \
# MSc Aerial Robotics, MSc BioRobotics, MSc Robotics                  2.0
# MSc Aerial Robotics, MSc Robotics                                   1.0
# MSc BioRobotics, MSc Robotics                                      12.0
# MSc Aerial Robotics                                                 3.0
# MSc BioRobotics                                                     2.0
# MSc Robotics                                                        NaN
#
#                                                     p:s_ratio
# MSc Aerial Robotics, MSc BioRobotics, MSc Robotics   2.500000
# MSc Aerial Robotics, MSc Robotics                   10.000000
# MSc BioRobotics, MSc Robotics                        3.583333
# MSc Aerial Robotics                                  3.333333
# MSc BioRobotics                                      3.500000
# MSc Robotics                                              NaN

# %%
sum_P_projects_ = np.array(sum_P_projects)[:5]

sum_P_supervisors_ = np.array(sum_P_supervisors)

print(sum_P_projects_)

print(sum_P_supervisors_)

print(sum_P_projects_ / sum_P_supervisors_)
# Out:
# [ 5. 10. 43. 10.  7.]
# [ 2.  1. 12.  3.  2.]
# [ 2.5        10.          3.58333333  3.33333333  3.5       ]

# %% [markdown]
# # Projects

# %%
projects = pd.read_excel('data/project_database_2021.xlsx', sheet_name='subjects')
projects.head()
# Out:
#    id                                              title  \
# 0   4                        Interactive expressive eyes
# 1   6                               Socially-aware robot
# 2   8               Neuromorphic whisker tactile sensing
# 3   9  Sign language detection for teaching applications
# 4  12                         Acoustic place recognition
#
#                                                 desc   supervisor  \
# 0  Gaze plays a key role in human-robot interacti...  s-lemaignan
# 1  The project deals with how robots can integrat...  s-lemaignan
# 2  Develop a neuromorphic whisker sensor that can...    m-pearson
# 3  Design a virtual environment for teachign sign...  a-tzemanaki
# 4  To integrate auditory cues into a multi-sensor...    m-pearson
#
#   cosupervisor assigned_student  is_cocreated  confirmation_email_sent  stall
# 0          NaN          fp20987           0.0                        0      0
# 1          NaN              NaN           NaN                        0      1
# 2          NaN          qb20314           0.0                        0      0
# 3          NaN              NaN           0.0                        0      0
# 4          NaN              NaN           0.0                        0      0

# %% [markdown]
# # UWE supervisors

# %%
cols = [ 'full_name', 'register',  'email', 'dept', 'N_proj', 'kwords']

resp_uwe = pd.read_excel('data/project_database_2021.xlsx', 
                               sheet_name='response_round_1_UWE', 
                               skiprows=3, 
                               names=cols)
resp_uwe.head()

primary_confirmed_UWE = set(resp_uwe.full_name) & set(supervisors[supervisors.UWE == 'X'].full_name)
primary_confirmed_UWE
# Out:
# {'Amir Bolouri',
#  'Chenguang Yang',
#  'David Western',
#  'Farid Dailami',
#  'Hamidreza Nemati',
#  'Manuel Giuliani',
#  'Mark Hansen',
#  'Martin Pearson',
#  'Matthew Studley',
#  'Ning Wang',
#  'Roshan Weerasekera',
#  'Tavs Jorgensen',
#  'Wenhao Zhang',
#  'Yaseen Zaidi'}

# %% [markdown]
# ## Create a new project database to be used for the app.

# %%
def project_data(primary_supers, uni, reponses):
    d = []

    for p in list(primary_supers):                             # for each primary supervisor who responded positively

        ID = f'{p.split()[0][0].lower()}-{p.split()[1].lower()}'  # create an ID initial-surname e.g h-philamore

        if uni=='UoB':
            prog = reponses[reponses.full_name == p]['prog'].values[0]
        else:
            prog = 'MSc Robotics'
            
        
        if not projects[projects.supervisor==ID].empty:           # if the supervisor has previously submitted a project...

            for index, row in projects[projects.supervisor==ID].iterrows():  # ... create an entry for the each project

                d.append(
                    {
                        'supervisor': p,
                        'second supervisor': '',
                        'email': supervisors[supervisors.full_name == p]['email'].values[0], 
                        'kwords': reponses[reponses.full_name == p]['kwords'].values[0], 
                        'prog': prog, # resp[resp.full_name == p]['prog'].values[0], 
                        'title': row['title'], 
                        'desc': row['desc'], 
                        'n_students': 1,
                        'uni': uni,
                    }
                )

        else:                                                                # ... otherwise create an empty entry with supervisor details only       
            d.append(
                {
                    'supervisor': p,
                    'second supervisor': ' ',
                    'email': supervisors[supervisors.full_name == p]['email'].values[0], 
                    'kwords': reponses[reponses.full_name == p]['kwords'].values[0], 
                    'prog': prog, # resp[resp.full_name == p]['prog'].values[0], 
                    'title': '', 
                    'desc': '', 
                    'uni': uni,
                }
            )



    app_list = pd.DataFrame(d)
    return app_list

# %%
d_UoB = project_data(primary_confirmed, 'UoB', resp)

d_UWE = project_data(primary_confirmed_UWE, 'UWE', resp_uwe)

# %%
d_all = pd.concat([d_UoB, d_UWE], axis=0)
d_all.head()
# Out:
#         supervisor second supervisor                          email  \
# 0  Arthur Richards                    arthur.richards@bristol.ac.uk
# 1  Arthur Richards                    arthur.richards@bristol.ac.uk
# 2  Arthur Richards                    arthur.richards@bristol.ac.uk
# 3  Arthur Richards                    arthur.richards@bristol.ac.uk
# 4  Arthur Richards                    arthur.richards@bristol.ac.uk
#
#                           kwords                               prog  \
# 0  Drones; Autonomy; Multi-agent  MSc Aerial Robotics, MSc Robotics
# 1  Drones; Autonomy; Multi-agent  MSc Aerial Robotics, MSc Robotics
# 2  Drones; Autonomy; Multi-agent  MSc Aerial Robotics, MSc Robotics
# 3  Drones; Autonomy; Multi-agent  MSc Aerial Robotics, MSc Robotics
# 4  Drones; Autonomy; Multi-agent  MSc Aerial Robotics, MSc Robotics
#
#                                          title  \
# 0           Drone path-planning with real maps
# 1  The Multi-Drone Failure Inspection Test-bed
# 2                       Optical Drone Guidance
# 3             Traffic Patterns for Drone Ports
# 4  Intelligent automated networks for mobility
#
#                                                 desc  n_students  uni
# 0  This project will exploit readily-available ge...         1.0  UoB
# 1  Inspection and maintenance is an important par...         1.0  UoB
# 2  Major airports provide simple coloured lights ...         1.0  UoB
# 3  Air traffic control relies on standard routes ...         1.0  UoB
# 4  This project will investigate how and where to...         1.0  UoB

# %%
# UoB project data

# d = []


# for p in list(primary_confirmed):                             # for each primary supervisor who responded positively
    
#     ID = f'{p.split()[0][0].lower()}-{p.split()[1].lower()}'  # create an ID initial-surname e.g h-philamore
    
#     if not projects[projects.supervisor==ID].empty:           # if the supervisor has previously submitted a project...
        
#         for index, row in projects[projects.supervisor==ID].iterrows():  # ... create an entry for the each project

#             d.append(
#                 {
#                     'supervisor': p,
#                     'second supervisor': '',
#                     'email': supervisors[supervisors.full_name == p]['email'].values[0], 
#                     'kwords': resp[resp.full_name == p]['kwords'].values[0], 
#                     'prog': resp[resp.full_name == p]['prog'].values[0], 
#                     'title': row['title'], 
#                     'desc': row['desc'], 
#                     'n_students': 1,
#                     'uni': 'UoB',
#                 }
#             )
            
#     else:                                                                # ... otherwise create an empty entry with supervisor details only       
#         d.append(
#             {
#                 'supervisor': p,
#                 'second supervisor': ' ',
#                 'email': supervisors[supervisors.full_name == p]['email'].values[0], 
#                 'kwords': resp[resp.full_name == p]['kwords'].values[0], 
#                 'prog': resp[resp.full_name == p]['prog'].values[0], 
#                 'title': '', 
#                 'desc': '', 
#                 'uni': 'UoB',
#             }
#         )
            
            

# app_list = pd.DataFrame(d)
# app_list.head()

# %%
# UWE project data

# y = []


# for p in list(primary_confirmed_UWE):                             # for each primary supervisor who responded positively
    
#     ID = f'{p.split()[0][0].lower()}-{p.split()[1].lower()}'  # create an ID initial-surname e.g h-philamore
    
#     #print(ID)
    
#     #print(projects[projects.supervisor==ID])
#     if not projects[projects.supervisor==ID].empty:           # if the supervisor has previously submitted a project...
        
#         for index, row in projects[projects.supervisor==ID].iterrows():  # ... create an entry for the each project

#             y.append(
#                 {
#                     'supervisor': p,
#                      'second supervisor': '',
#                      'email': supervisors[supervisors.full_name == p]['email'].values[0], 
#                     'kwords': resp_uwe[resp_uwe.full_name == p]['kwords'].values[0], 
#                     'prog': 'Robotics', 
#                     'title': row['title'], 
#                     'desc': row['desc'], 
#                     'n_students': 1,
#                     'uni': 'UWE',
#                 }
#             )
            
#     else:                                                                # ... otherwise create an empty entry with supervisor details only       
#         y.append(
#             {
#                 'supervisor': p,
#                 'second supervisor': ' ',
#                 'email': supervisors[supervisors.full_name == p]['email'].values[0], 
#                 'kwords': resp_uwe[resp_uwe.full_name == p]['kwords'].values[0], 
#                 'prog': 'Robotics', 
#                 'title': '', 
#                 'desc': '', 
#                 'n_students': 1,
#                 'uni': 'UWE',
#             }
#         )
            
            

# app_list_uwe = pd.DataFrame(y)
# app_list_uwe.head()

# %% [markdown]
# ## Save the new sheet to the project database

# %%
filename = 'data/project_database_2021.xlsx'

# Properly load the workbook
excel_book = pxl.load_workbook(filename)

# Handle everything related to writing new data to the file without overwriting existing data
with pd.ExcelWriter(filename, engine='openpyxl') as writer:

    writer.book = excel_book

    # Loop through the existing worksheets in the workbook and map each title to\
    # the corresponding worksheet (that is, a dictionary where the keys are the\
    # existing worksheets' names and the values are the actual worksheets)
    writer.sheets = {worksheet.title: worksheet for worksheet in excel_book.worksheets}


    # Write the new data to the file without overwriting what already exists
    #app_list.to_excel(writer, 'projects', index=False)
    d_all.to_excel(writer, 'projects', index=False)

    # Save the file
    writer.save()

# %%
print(sum(resp[resp.prog=='MSc Aerial Robotics, MSc BioRobotics, MSc Robotics']['N_proj']))
resp[resp.prog=='MSc Aerial Robotics, MSc BioRobotics, MSc Robotics'][['full_name', 'N_proj']]
# Out:
# 5.0
#                  full_name  N_proj
# 26          Sebastian East     2.0
# 29  Mohammad Naghavi Zadeh     1.0
# 49   Walterio Mayol-Cuevas     2.0

# %%
print(sum(resp[resp.prog=='MSc Aerial Robotics, MSc Robotics']['N_proj']))
resp[resp.prog=='MSc Aerial Robotics, MSc Robotics'][['full_name', 'N_proj']]
# Out:
# 10.0
#                full_name  N_proj
# 18  Lucio Rafael Salinas     1.0
# 20       Arthur Richards     3.0
# 21      Christian Romero     2.0
# 24        Hirad Goudarzi     1.0
# 27              Yuan Gao     2.0
# 28             Mickey Li     1.0

# %%
print(sum(resp[resp.prog=='MSc BioRobotics, MSc Robotics']['N_proj']))
resp[resp.prog=='MSc BioRobotics, MSc Robotics'][['full_name', 'N_proj']]
# Out:
# 43.0
#                  full_name  N_proj
# 0          Hemma Philamore     3.0
# 1            Helmut Hauser     3.0
# 3             Dandan Zhang     5.0
# 6              Paul O'Dowd     5.0
# 7   Benjamin Ward-Cherrier     2.0
# 8            Nahian Rahman     0.0
# 12          Hermes Gadelha     2.0
# 14               Qiukai Qi     2.0
# 15             Edmund Hunt     2.0
# 17            James Wilson     2.0
# 22             Andrew Conn     2.0
# 25           Martin Garrad     1.0
# 30            Chanelle Lee     2.0
# 31           Nathan Lepora     2.0
# 42            James Wilson     2.0
# 51           Sabine Hauert     5.0
# 53           Elliott Scott     1.0
# 54             Edmund Hunt     2.0

# %%
print(sum(resp[resp.prog=='MSc Aerial Robotics']['N_proj']))
resp[resp.prog=='MSc Aerial Robotics'][['full_name', 'N_proj']]
# Out:
# 10.0
#          full_name  N_proj
# 23   Shane Windsor     5.0
# 45  Tom Richardson     4.0
# 48  Sebastian East     1.0

# %%
print(sum(resp[resp.prog=='MSc BioRobotics']['N_proj']))
resp[resp.prog=='MSc BioRobotics'][['full_name', 'N_proj']]
# Out:
# 7.0
#             full_name  N_proj
# 10          Keren Yue     2.0
# 13          Qiukai Qi     2.0
# 50      Lucia Marucci     1.0
# 55     Conor Houghton     1.0
# 56  Johanna Benn-Blee     1.0

# %%
print(sum(resp[resp.prog=='MSc Robotics']['N_proj']))
resp[resp.prog=='MSc Robotics'][['full_name', 'N_proj']]
# Out:
# 4.0
#                       full_name  N_proj
# 5                 Andrew Hinitt     1.0
# 16  Richard Suphapol Diteesawat     2.0
# 32              Efi Psomopoulou     1.0

# %%
#resp.groupby('dept').count()

# %%
#resp.groupby('prog').count().drop('NaN', axis=0)
