# %%
import numpy as np
from numpy import pi as pi
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# bi-state 0 = bend to left
# bi_state 1 = bend to right
# COA = central point of actuator 

def actuator_top(n, radius = 27, bi_states = [0, 0, 0, 1], arc_angle = 0.93, COA = [0, 0]): 
    "2D plot of series linked, bistable actuators"
    
    numsegments = 1000
    x = 0
    y = 1
    
    # the actuator centre is atthe midpoint of the chord of the first (vertically alligned) link
    state = bi_states[n-1]
    print("state", state)

    
    if n == 1:        
        # define the angle of start of arc relative to horizontal datum
        start_angle = 0 - (arc_angle / 2) 
        
        # define the origin of the arc
        sagitta = radius * (1 - np.cos(arc_angle / 2))
        origin = np.array(COA)
        origin[x] += (radius - sagitta) * (-1 if state else 1) 
        
    
    else:            
        # define the angle of start of arc relative to horizontal datum
        start_angle, origin, start_point = actuator_top(n-1)
        print("start_angle", start_angle)
        print("origin", origin)
        print("start_point", start_point)
        
        # if the bistable state is not same as previous link ... 
        if bi_states[n-1]!=bi_states[n-2]:
            # mirror location of the origin of the arc
            origin = start_point + np.array([radius * np.cos(start_angle) * (-1 if state else 1),
                                             radius * np.sin(start_angle)])
            print("origin changed to", origin)
            
            # invert sign of angle that end_point-origin makes with horizontal datum
            start_angle *= -1
            print("start_angle changed to", start_angle)
            

    # plot link as arc
    arc_points = np.linspace(start_angle, 
                             start_angle + arc_angle, 
                             numsegments)    

    arc = np.array([origin[x] + radius * (np.cos(arc_points) * (1 if state else -1)), 
                    origin[y] + radius *  np.sin(arc_points)])
   
    plt.plot(arc[x], arc[y])

    # angle that end_point-origin makes with horizontal datum     
    #end_angle = np.arcsin(abs(arc[y, -1] - origin[y]) / radius) 
    acute_angle = np.arcsin(abs( origin[y] - arc[y, -1] ) / radius) 
    end_angle = ((pi - acute_angle)  if (( origin[y]  - arc[y, -1] ) > 0) else acute_angle)
    print("start angle = ", start_angle)
    end_point = arc[:, -1]
    
    print("start_angle", end_angle)
    print("origin", origin)
    print("start_point", end_point)
    print()
        
    return end_angle, origin, end_point         
  
    
F = actuator_top(4)
plt.xlim(0, 40)
plt.ylim(0, 40)
plt.axis('equal')        
print(F)
# Out:
# state 1
# state 0
# state 0
# state 0
# start angle =  -0.465
# start_angle 0.465
# origin [24  0]
# start_point [-0.13318227 12.10741564]
#
# start_angle 0.465
# origin [24  0]
# start_point [-0.13318227 12.10741564]
# start angle =  0.465
# start_angle 1.3950000000000002
# origin [24  0]
# start_point [19.27790935 26.58386465]
#
# start_angle 1.3950000000000002
# origin [24  0]
# start_point [19.27790935 26.58386465]
# start angle =  1.3950000000000002
# start_angle 0.8165926535897932
# origin [24  0]
# start_point [42.48712975 19.6780597 ]
#
# start_angle 0.8165926535897932
# origin [24  0]
# start_point [42.48712975 19.6780597 ]
# origin changed to [24.        39.3561194]
# start_angle changed to -0.8165926535897932
# start angle =  -0.8165926535897932
# start_angle 0.11340734641020689
# origin [24.        39.3561194]
# start_point [50.82655945 42.41155846]
#
# (0.11340734641020689, array([24.       , 39.3561194]), array([50.82655945, 42.41155846]))

# %%
def actuator_bottom(n, radius = 27, bi_states = [1, 0, 0, 0], arc_angle = 0.93, COA = [0, 0]): 
    "2D plot of series linked, bistable actuators"
    numsegments = 1000
    x = 0
    y = 1
    
    # the actuator centre is atthe midpoint of the chord of the first (vertically alligned) link
    state = bi_states[n-1]
    
    if n == 1:        
        # define the angle of start of arc relative to horizontal datum
        start_angle = 0 - (arc_angle / 2) 
        
        # define the origin of the arc
        sagitta = radius * (1 - np.cos(arc_angle / 2))
        origin = np.array(COA)
        origin[x] += (radius - sagitta) * (-1 if state else 1) 
        
    # if the bistable state is not same as previous link ... 
    if bi_states[n-1]!=bi_states[n-2]:
        # mirror location of the origin of the arc
        origin = start_point + np.array([radius * np.cos(start_angle),
                                         radius * np.sin(start_angle)])

        # invert sign of angle that end_point-origin makes with horizontal datum
        start_angle *= -1

# %%
# bi-state 0 = bend to left
# bi_state 1 = bend to right
# COA = central point of actuator 

def actuator_top(n, radius = 27, bi_states = [1, 1, 1, 1], arc_angle = 0.93, COA = [0, 0]): 
    "2D plot of series linked, bistable actuators"
    
    numsegments = 1000
    x = 0
    y = 1
    
    # the actuator centre is atthe midpoint of the chord of the first (vertically alligned) link
    state = bi_states[n-1]
    
    
    if n == 1:        
        # define the angle of start of arc relative to horizontal datum
        start_angle = 0 - (arc_angle / 2) 
        
        # define the origin of the arc
        sagitta = radius * (1 - np.cos(arc_angle / 2))
        origin = np.array(COA)
        origin[x] += (radius - sagitta) * (-1 if state else 1) 
        
    
    else:            
        # define the angle of start of arc relative to horizontal datum
        start_angle, origin, start_point = f(n-1)
        print(start_angle, origin, start_point)
        
        # if the bistable state is not same as previous link ... 
        if bi_states[n-1]!=bi_states[n-2]:
            # mirror location of the origin of the arc
            origin = start_point + np.array([radius * np.cos(start_angle) * (-1 if state else 1),
                                             radius * np.sin(start_angle)])
            
            # invert sign of angle that end_point-origin makes with horizontal datum
            start_angle *= -1
            

    # plot link as arc
    arc_points = np.linspace(start_angle, 
                             start_angle + arc_angle, 
                             numsegments)    

    arc = np.array([origin[x] + radius * (np.cos(arc_points) * (1 if state else -1)), 
                    origin[y] + radius *  np.sin(arc_points)])
    
    print(arc)
    print(arc[:, -1])
    
    plt.plot(arc[x], arc[y])

    # angle that end_point-origin makes with horizontal datum 
    print(arc[y, -1] - origin[y])
    
    # start_angle = np.arcsin(abs(arc[y, -1] - origin[y]) / radius) 
    acute_angle = np.arcsin(abs( origin[y] - arc[y, -1] ) / radius) 
    end_angle = ((pi - acute_angle)  if (( origin[y]  - arc[y, -1] ) > 0) else acute_angle)
    print("start angle = ", start_angle)
    end_point = arc[:, -1]
    return end_angle, origin, end_point
    
    

    
#     arc[y] = (origin[y] + radius) * np.sin(arc_points)
#     arc[0] =  np.linspace(start_angle, 
#                              start_angle + arc_angle, 
#                              numsegments)
    
#     arc[x] = origin[x] + radius #* (np.cos(arc_points) * (1 if state else -1))
    

    


#     arc_y = origin[y] + radius * np.sin(arc_points)
    
#     if state:
#         arc_x = origin[x] + radius * np.cos(arc_points)
#     else: 
#         arc_x = origin[x] - radius * np.cos(arc_points)

#     plt.plot(arc_x, arc_y)

#     # the angle the end of the arc makes with the horizontal datum 
#     theta = np.arcsin(abs(arc_y - origin[y]) / radius)        
#     return theta  # This doesn't call f, so it breaks out of the recursion loop
            
        
        
            
        
F = actuator_top(2)
plt.xlim(0, 40)
plt.ylim(0, 40)
plt.axis('equal')        
print(F)  
print()
# Out:
# (2, 1000)
# 0.465 [-24   0] [ 0.13318227 12.10741564]
# [[  0.13318227   0.12190065   0.11059812 ... -19.22842208 -19.25316365
#   -19.27790935]
#  [ 12.10741564  12.12987672  12.15232728 ...  26.5750267   26.57945719
#    26.58386465]]
# [-19.27790935  26.58386465]
# 26.583864652412313
# start angle =  1.3950000000000002
# (1.3950000000000002, array([-24,   0]), array([-19.27790935,  26.58386465]))
#
# (2, 1000)
# (2, 1000)
# 0.46500000000000014 [24.26636454 24.21483128] [ 0.13318227 36.32224692]
# [[48.39954681 48.38826519 48.37696266 ... 29.03794247 29.01320089
#   28.9884552 ]
#  [36.32224692 36.34470799 36.36715856 ... 50.78985798 50.79428847
#   50.79869593]]
# [28.9884552  50.79869593]
# 26.58386465241231
# start angle =  1.394999999999999
# (1.394999999999999, array([24.26636454, 24.21483128]), array([28.9884552 , 50.79869593]))
